# %%
import geopandas as gpd
import matplotlib.pyplot as plt
'''
df = pd.DataFrame(
    {'City': ['Buenos Aires', 'Brasilia', 'Santiago', 'Bogota', 'Caracas'],
     'Country': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Venezuela'],
     'Latitude': [-34.58, -15.78, -33.45, 4.60, 10.48],
     'Longitude': [-58.66, -47.91, -70.66, -74.08, -66.86]})
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))
'''
map_data = geopandas.read_file('natalidad.geojson')

# We restrict to South America.
ax = world.plot(color='white', edgecolor='black')

# We can now plot our ``GeoDataFrame``.
#gdf.plot(ax=ax, color='red')

plt.show()

# %%
world
# Out:
#                         NAME_1                  NAME_2 CC_2  NAT2018  \
# 0                    Andalucía                 Almería   04    10.48
# 1                    Andalucía                   Cádiz   11     8.11
# 2                    Andalucía                 Córdoba   14     7.90
# 3                    Andalucía                 Granada   18     7.78
# 4                    Andalucía                  Huelva   21     7.57
# 5                    Andalucía                    Jaén   23     7.68
# 6                    Andalucía                  Málaga   29     8.14
# 7                    Andalucía                 Sevilla   41     8.71
# 8                       Aragón                  Huesca   22     7.51
# 9                       Aragón                  Teruel   44     7.10
# 10                      Aragón                Zaragoza   50     7.64
# 11                   Cantabria               Cantabria   39     6.55
# 12          Castilla-La Mancha                Albacete   02     7.75
# 13          Castilla-La Mancha             Ciudad Real   13     7.41
# 14          Castilla-La Mancha                  Cuenca   16     6.29
# 15          Castilla-La Mancha             Guadalajara   19     8.20
# 16          Castilla-La Mancha                  Toledo   45     8.24
# 17             Castilla y León                   Ávila   05     6.15
# 18             Castilla y León                  Burgos   09     6.62
# 19             Castilla y León                    León   24     5.68
# 20             Castilla y León                Palencia   34     6.08
# 21             Castilla y León               Salamanca   37     6.23
# 22             Castilla y León                 Segovia   40     6.85
# 23             Castilla y León                   Soria   42     6.78
# 24             Castilla y León              Valladolid   47     6.65
# 25             Castilla y León                  Zamora   49     5.13
# 26                    Cataluña               Barcelona   08     8.15
# 27                    Cataluña                  Girona   17     8.95
# 28                    Cataluña                  Lleida   25     8.11
# 29                    Cataluña               Tarragona   43     8.26
# 30         Comunidad de Madrid                  Madrid   28     8.70
# 31  Comunidad Foral de Navarra                 Navarra   31     8.34
# 32        Comunidad Valenciana                Alicante   03     7.63
# 33        Comunidad Valenciana               Castellón   12     8.03
# 34        Comunidad Valenciana                Valencia   46     7.60
# 35                 Extremadura                 Badajoz   06     7.73
# 36                 Extremadura                 Cáceres   10     6.62
# 37                     Galicia                A Coruña   15     6.36
# 38                     Galicia                    Lugo   27     5.94
# 39                     Galicia                 Ourense   32     4.82
# 40                     Galicia              Pontevedra   36     6.35
# 41              Islas Baleares                Baleares   07     8.71
# 42              Islas Canarias              Las Palmas   35     6.83
# 43              Islas Canarias  Santa Cruz de Tenerife   38     6.54
# 44                    La Rioja                La Rioja   26     7.45
# 45                  País Vasco                   Álava   01     8.22
# 46                  País Vasco               Guipúzcoa   20     7.68
# 47                  País Vasco                 Vizcaya   48     6.99
# 48      Principado de Asturias                Asturias   33     5.60
# 49            Región de Murcia                  Murcia   30     9.86
#
#                                              geometry
# 0   MULTIPOLYGON (((-3.03042 35.94236, -3.03042 35...
# 1   MULTIPOLYGON (((-6.21958 36.38110, -6.21958 36...
# 2   MULTIPOLYGON (((-5.04854 37.63690, -5.04667 37...
# 3   MULTIPOLYGON (((-3.35014 36.72952, -3.35014 36...
# 4   MULTIPOLYGON (((-6.83648 37.11547, -6.83643 37...
# 5   MULTIPOLYGON (((-3.00812 37.60799, -3.02137 37...
# 6   MULTIPOLYGON (((-4.00083 36.73986, -4.00153 36...
# 7   MULTIPOLYGON (((-5.94118 36.85199, -5.95270 36...
# 8   MULTIPOLYGON (((0.34747 41.42733, 0.34187 41.4...
# 9   MULTIPOLYGON (((0.02648 40.69497, 0.02688 40.7...
# 10  MULTIPOLYGON (((0.14589 41.06306, 0.14458 41.0...
# 11  MULTIPOLYGON (((-3.90653 43.47792, -3.90653 43...
# 12  MULTIPOLYGON (((-2.76198 38.53278, -2.76382 38...
# 13  MULTIPOLYGON (((-4.94063 39.39513, -4.94171 39...
# 14  MULTIPOLYGON (((-2.66225 39.32198, -2.66506 39...
# 15  MULTIPOLYGON (((-3.37095 40.62496, -3.38198 40...
# 16  MULTIPOLYGON (((-5.33994 39.89062, -5.36937 39...
# 17  MULTIPOLYGON (((-4.45362 40.33298, -4.45541 40...
# 18  MULTIPOLYGON (((-4.24498 42.73595, -4.25125 42...
# 19  MULTIPOLYGON (((-4.98658 42.29383, -4.98982 42...
# 20  MULTIPOLYGON (((-4.10266 42.13722, -4.10996 42...
# 21  MULTIPOLYGON (((-5.51100 40.42803, -5.51348 40...
# 22  MULTIPOLYGON (((-4.36461 40.63750, -4.38849 40...
# 23  MULTIPOLYGON (((-2.10146 41.44580, -2.10362 41...
# 24  MULTIPOLYGON (((-5.30633 42.27157, -5.30165 42...
# 25  MULTIPOLYGON (((-6.13438 41.19038, -6.14344 41...
# 26  MULTIPOLYGON (((2.17292 41.33958, 2.17292 41.3...
# 27  MULTIPOLYGON (((3.18792 41.86319, 3.18792 41.8...
# 28  MULTIPOLYGON (((1.70599 41.88941, 1.70780 41.8...
# 29  MULTIPOLYGON (((0.72958 40.78069, 0.72958 40.7...
# 30  MULTIPOLYGON (((-4.27502 40.67631, -4.26984 40...
# 31  MULTIPOLYGON (((-1.84713 42.00800, -1.84898 42...
# 32  MULTIPOLYGON (((-0.45708 38.16208, -0.45708 38...
# 33  MULTIPOLYGON (((0.68736 39.90070, 0.68736 39.9...
# 34  MULTIPOLYGON (((-1.20709 40.00186, -1.21656 40...
# 35  MULTIPOLYGON (((-7.04542 38.18510, -7.04546 38...
# 36  MULTIPOLYGON (((-5.92458 39.08319, -5.93753 39...
# 37  MULTIPOLYGON (((-9.01514 42.48764, -9.01514 42...
# 38  MULTIPOLYGON (((-7.62931 43.76181, -7.62931 43...
# 39  MULTIPOLYGON (((-7.03390 42.07154, -7.03086 42...
# 40  MULTIPOLYGON (((-8.91042 42.18042, -8.91042 42...
# 41  MULTIPOLYGON (((1.42514 38.77681, 1.42514 38.7...
# 42  MULTIPOLYGON (((-15.36375 27.99291, -15.36375 ...
# 43  MULTIPOLYGON (((-18.04792 27.69042, -18.04819 ...
# 44  MULTIPOLYGON (((-2.65973 42.00536, -2.66180 42...
# 45  MULTIPOLYGON (((-3.13116 42.75807, -3.14786 42...
# 46  MULTIPOLYGON (((-2.59676 42.97596, -2.60264 42...
# 47  MULTIPOLYGON (((-2.49458 43.36819, -2.49458 43...
# 48  MULTIPOLYGON (((-6.03181 43.59125, -6.03181 43...
# 49  MULTIPOLYGON (((-1.54680 37.40990, -1.54681 37...

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
 
# Control del encuadre (área geográfica) del mapa
ax.axis([-12, 5, 32, 48])
 
# Control del título y los ejes
ax.set_title('Natalidad por Provincias en España, 2018', 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#4873ab'})
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
 
# Añadir la leyenda separada del mapa
from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.2)
 
# Generar y cargar el mapa
map_data.plot(column='NAT2018', cmap='plasma', ax=ax,
              legend=True, cax=cax, zorder=5)
 
# Cargar un mapa base con contornos de países
oceanos = "natural_earth/ne_50m_ocean.shp"
map_oceanos = gpd.read_file(oceanos)
map_oceanos.plot(ax=ax, color='#89c0e8', zorder=0)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: natural_earth/ne_50m_ocean.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-11-864228944ebb> in <module>
#      22 # Cargar un mapa base con contornos de países
#      23 oceanos = "natural_earth/ne_50m_ocean.shp"
# ---> 24 map_oceanos = gpd.read_file(oceanos)
#      25 map_oceanos.plot(ax=ax, color='#89c0e8', zorder=0)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/geopandas/io/file.py in read_file(filename, bbox, mask, rows, **kwargs)
#      87
#      88     with fiona_env():
# ---> 89         with reader(path_or_bytes, **kwargs) as features:
#      90
#      91             # In a future Fiona release the crs attribute of features will
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     396     def wrapper(*args, **kwargs):
#     397         if local._env:
# --> 398             return f(*args, **kwargs)
#     399         else:
#     400             if isinstance(args[0], str):
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     252         if mode in ('a', 'r'):
#     253             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 254                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     255         elif mode == 'w':
#     256             if schema:
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     152             if self.mode == 'r':
#     153                 self.session = Session()
# --> 154                 self.session.start(self, **kwargs)
#     155             elif self.mode in ('a', 'w'):
#     156                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: natural_earth/ne_50m_ocean.shp: No such file or directory

# %%
pts = gpd.GeoDataFrame.from_file('points_demo.shp')
print("Hecho")
pts.plot()
plt.show()
